# %% [markdown]
# # Exercise 4.6

# %% [markdown]
# ### Importing Libraries and Dataframe

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\steve\Documents\CF - Instacart Project\02 Data'

# %%
# Defining dataframe using read_pickles from Pandas library
df_ords = pd.read_csv(os.path.join(path, 'Prepared Data', 'orders_products_combined.csv'))

# %%
# Adding products_checked csv per task
df_prods = pd.read_csv(os.path.join(path,'Prepared Data', 'products_checked.csv'))

# %%
# Checking shape of the dataframe
df_ords.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### Checking on Table Content to Visualize

# %%
# Checking both dataframes to see where I can join the tables
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# I think I can link them on product_id, but I want to see what the result may be
df_prods[df_prods['product_id']==14084]
# Out:
#        Unnamed: 0  product_id                             product_name  \
# 14069       14084       14084  Organic Unsweetened Vanilla Almond Milk
#
#        aisle_id  department_id  prices
# 14069        91             16    12.5

# %%
# Test merge, just in case
pd.merge(df_ords, df_prods, on='product_id')
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 0                         8                    NaN         196
# 1                         7                   15.0         196
# ...

# %%
# Have to remove current _merge column, could rename it but there's no use for it right nowb
df_ords = df_ords.drop(columns=['_merge'])

# %%
df_ords = df_ords.drop(columns=['Unnamed: 0'])

# %%
# Also dropping the unnamed: 0 column in df_prods, looks to just be a numbering of rows
df_prods = df_prods.drop(columns=['Unnamed: 0'])

# %%
# The big merge! Hope it works
df_merged = df_ords.merge(df_prods, on='product_id')

# %%
# Running checks on what it looks like, the shape, and counts of "both" for _merge
df_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices
# 0         Soda        77              7     9.0
# ...

# %%
df_merged.shape
# Out:
# (32404859, 13)

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged = df_merged.drop(columns=['_merge'])

# %% [markdown]
# #### Exporting Dataframe

# %%
# For pickled file
df_merged.to_pickle(os.path.join(path,'Prepared Data','orders_products_merged.pkl'))

# %%
# For csv file
df_merged.to_csv(os.path.join(path,'Prepared Data', 'orders_products_merged.csv'))

# %% [markdown]
# Initially it was taking a while and then I realized I had to_csv, and saved it as a .pkl file... whoops.  Corrected that and it was instant almost.

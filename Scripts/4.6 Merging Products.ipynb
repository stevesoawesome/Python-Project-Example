# %% [markdown]
# ## Merging Products

# %% [markdown]
# ### Importing Libraries & Path

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\steve\Documents\CF - Instacart Project\02 Data'

# %%
# Importing orders_products_prior.csv
df_ords_prior = pd.read_csv(os.path.join(path,'Original Data','orders_products_prior.csv'))
# Adding orderse_checked.csv, wasn't specified in steps but necessary
df_ords = pd.read_csv(os.path.join(path,'Prepared Data','orders_checked.csv'))

# %% [markdown]
# ### Checking Dimensions

# %%
# Checking rows and content for df_ords_prior
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Checking rows and content for df_ords
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %% [markdown]
# Note: I actually didn't realize there were detailed steps in the achievement... so I've been doing all the steps till now based on the bullet points.  Saw that the steps were the same during the achievement's guided section and felt pretty accomplished.  Good job me!

# %%
# Merging on order_id and checking indicators for match
df_merged_large = df_ords.merge(df_ords_prior, on ='order_id', indicator = True)

# %%
# Checking table and shape to verify all went well
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge
# 0                    NaN         196                  1          0   both
# 1                    NaN       14084                  2          0   both
# 2                    NaN       12427                  3          0   both
# 3                    NaN       26088                  4          0   both
# 4                    NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### Test Check

# %%
# I didn't fully understand what the join meant and speculated that it should have every order for one user organized
# So I tested that by creating this subset and am exporting it to play around in SQL/pgAdmin
testcheck = df_merged_large[df_merged_large['user_id']==1]

# %%
testcheck
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# 5    2398795        1             2                  3                  7
# 6    2398795        1             2                  3                  7
# 7    2398795        1             2                  3                  7
# 8    2398795        1             2                  3                  7
# 9    2398795        1             2                  3                  7
# 10   2398795        1             2                  3                  7
# 11    473747        1             3                  3                 12
# ...

# %%
testcdheck.to_csv(os.path.join(path,'Prepared Data','practice.csv'))

# %% [markdown]
# ### Exporting

# %%
# Exporting as .csv to see how long it takes
df_merged_large.to_csv(os.path.join(path, 'Prepared Data', 'orders_products_combined.csv'))

# %%
# Export data to pkl
df_merged_large.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# The csv took about 6 mins, the pkl file was instant almost - with that said, the pkl file was 1.5x the size of the csv.
